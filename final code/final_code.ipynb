# %%
import numpy as np # importing necessary libraries
import pandas as pd
import csv
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize  # necessary libraries for Natural Language Processing
from nltk.corpus import stopwords
import string
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
#training data
train = pd.read_csv('/Users/hardikdudeja/Downloads/train_final (1).csv') #reading the data into pandas dataframe
train
# Out:
#                                                    TITLE  \
# 0                          Get Glamr Burne Loafers Black
# 1      TRASE Filo Blue Women Slippers and Flip Flops ...
# 2      ARWY Car Stickers ' Torque Racing ' (Size -20 ...
# 3      in-Ear Headphones YR Earphones for Moto G6 Ear...
# 4                  Roshiaaz Checks Pattern Backpack Bags
# ...                                                  ...
# 99995  Ana Rugs Industries Floral Carpet for Living R...
# 99996  Generic Electric Head Massager Helmet Scalp Br...
# 99997        Silverwala 925 Sterling Silver Plain Locket
# 99998  SellZone Laptop Battery for HP Pavilion 15-BW0...
# 99999  AKC Laptop Battery Compatible for Pavilion G6-...
#
#                                              DESCRIPTION  \
# 0      For a casual guy that takes pride in staying i...
# 1      Make a note to get noticed as you adorn this p...
# 2      Our Car Stickers Comes In Standard Internation...
# 3      This light hands free also allows you to take ...
# 4      This school/ casual backpack will keep items c...
# ...                                                  ...
# 99995  The Unmatched softness of Silk and Viscose thr...
# 99996  Features: Adopts smart physical, micro compute...
# 99997  An Antique Finishing Lizard Locket made in 925...
# 99998                      Picture is for reference only
# 99999  AKC Laptop Battery Compatible for Pavilion G6-...
#
#                                            BULLET_POINTS                BRAND  \
# 0      [Casuals Shoes,Loafers,Flat Loafers,Mens Loafe...            Get Glamr
# 1      [Material : Artificial Leather / Rexine (Durab...                TRASE
# 2      [Premium Quality - Automotive Grade High Quali...                 ARWY
# 3      [In-ear headphones provide comfort, quality, a...         ShopsGeniune
# 4      [Style: Casual backpack bags,These backpacks p...             Roshiaaz
# ...                                                  ...                  ...
# 99995  [Persian Design carpet,Binding on edge and can...  Ana Rugs Industries
# 99996  [Features: Adopts smart physical, micro comput...              Generic
# 99997  [Material: 92.5 Sterling Silver; Color: Silver...           Silverwala
# 99998  [Genuine quality product,Tested before shippin...             SellZone
# 99999  [AKC Laptop Battery Compatible for Hp G4 G6 G7...                  AKC
#
#        BROWSE_NODE_ID  NODE_ID
# 0                 368       82
# 1                 311       75
# 2                 787       48
# 3                 811       40
# 4                1454       96
# ...               ...      ...
# 99995             324       22
# 99996             800       60
# 99997             761       59
# 99998            1163       66
# 99999            1163       66
#
# [100000 rows x 6 columns]

# %%
# converting documents into a single text
documents = [] #contains each document in the form of tuple
for i in range(len(train)):  # making a single text paragraph from important attributes
    text = ""
    title = train.iloc[i]['TITLE']
    description = train.iloc[i]['DESCRIPTION']
    points = train.iloc[i]['BULLET_POINTS']
    brand = train.iloc[i]['BRAND']
    class_val = train.iloc[i]['NODE_ID']
    text += brand + " " + title + " " + description + " " + points
    documents.append((text, class_val)) # adding the text into array along with its category in the form of a tuple
    if(i%100 == 0):
        print(i)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900

# %%
# splitting each document into array of words so as to apply necessary processing for NLP
documents_words = [(word_tokenize(document), category) for document, category in documents]

# %%
#creating a list of stop words and dictionaries
stops = set(stopwords.words('english'))
punctuations = list(string.punctuation)
stops.update(punctuations)

# %%
def get_simple_pos(tag): # returns the simple part of speech that lemmatization takes as input
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    return wordnet.NOUN

# %%
lemmatizer = WordNetLemmatizer() # initialising the lemmatizer
def clean_document(words): # cleaning every document, removing stop words ans punctuations
    output_words = []
    for w in words:
        w = w.strip() # removing beginning and trailing spaces
        if w.lower() not in stops and w.isnumeric() == False and w != 'Generic' and len(w) > 2:
            pos = pos_tag([w])
            clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1])) # lemmatisation of a word
            output_words.append(clean_word.lower()) # adding clean words into a new array
    return output_words

# %%
documents_words_clean = []
for i in range(len(documents_words)): # cleaningevery document
    clean_doc = clean_document(documents_words[i][0])
    category = documents_words[i][1]
    documents_words_clean.append((clean_doc, category))
    if(i%100 == 0):
        print(i)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a04e611991fb> in <module>
#       1 documents_words_clean = []
#       2 for i in range(len(documents_words)): # cleaningevery document
# ----> 3     clean_doc = clean_document(documents_words[i][0])
#       4     category = documents_words[i][1]
#       5     documents_words_clean.append((clean_doc, category))
#
# <ipython-input-8-48c8dfd0ffb6> in clean_document(words)
#       5         w = w.strip() # removing beginning and trailing spaces
#       6         if w.lower() not in stops and w.isnumeric() == False and w != 'Generic' and len(w) > 2:
# ----> 7             pos = pos_tag([w])
#       8             clean_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1])) # lemmatisation of a word
#       9             output_words.append(clean_word.lower()) # adding clean words into a new array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     162     :rtype: list(tuple(str, str))
#     163     """
# --> 164     tagger = _get_tagger(lang)
#     165     return _pos_tag(tokens, tagset, tagger, lang)
#     166
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     104         tagger.load(ap_russian_model_loc)
#     105     else:
# --> 106         tagger = PerceptronTagger()
#     107     return tagger
#     108
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tag/perceptron.py in __init__(self, load)
#     166         if load:
#     167             AP_MODEL_LOC = "file:" + str(
# --> 168                 find("taggers/averaged_perceptron_tagger/" + PICKLE)
#     169             )
#     170             self.load(AP_MODEL_LOC)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/data.py in find(resource_name, paths)
#     506     :rtype: str
#     507     """
# --> 508     resource_name = normalize_resource_name(resource_name, True)
#     509
#     510     # Resolve default paths at runtime in-case the user overrides
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/data.py in normalize_resource_name(resource_name, allow_relative, relative_path)
#     228     True
#     229     """
# --> 230     is_dir = bool(re.search(r"[\\/.]$", resource_name)) or resource_name.endswith(
#     231         os.path.sep
#     232     )
#
# ~/opt/anaconda3/lib/python3.8/re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# KeyboardInterrupt:

# %%
doc_words = [document for document, category in documents_words_clean] # adding final words of a document into list
categories = [category for document, category in documents_words_clean] # adding category of a document into list

# %%
# making a single text paragraph from resultant clean words
text_documents = [" ".join(document) for document in doc_words]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
# splitting the data into training and testing
x_train, x_test, y_train, y_test = train_test_split(text_documents, categories, random_state = 0)

# %%
# count vectorizer attempt default params
count_vec_1 = CountVectorizer(max_features=2000)
x_train_features_1 = count_vec_1.fit_transform(x_train)
x_test_features_1 = count_vec_1.transform(x_test)
dict_words_1 = count_vec_1.vocabulary_

# %%
keys = dict_words_1.keys()
values = dict_words_1.values()
keys = np.array(list(keys))
values = np.array(list(values))

order = np.argsort(values)[::-1]
keys = keys[order]
values = values[order]

for i in range(2000):
    print(keys[i], values[i])
# Out:
# zirconia 1999
# zipper 1998
# zip 1997
# youth 1996
# young 1995
# you 1994
# yoga 1993
# yet 1992
# yes 1991
# yellow 1990
# years 1989
# year 1988
# yarn 1987
# yantra 1986
# xxl 1985
# xl 1984
# xiaomi 1983
# write 1982
# wrist 1981
# wrinkle 1980
# wrap 1979
# woven 1978
# would 1977
# worth 1976
# worry 1975
# worn 1974
# world 1973
# workout 1972
# workmanship 1971
# work 1970
# wool 1969
# wooden 1968
# wood 1967
# wonderful 1966
# womens 1965
# women 1964
# woman 1963
# without 1962
# within 1961
# wish 1960
# wireless 1959
# wired 1958
# wire 1957
# wipe 1956
# winter 1955
# window 1954
# wind 1953
# wife 1952
# width 1951
# wide 1950
# artwork 141
# arts 140
# artistic 139
# artist 138
# artisan 137
# artificial 136
# art 135
# around 134
# arm 133
# area 132
# approx 131
# apply 130
# application 129
# applicable 128
# apple 127
# appearance 126
# appeal 125
# apparel 124
# apart 123
# anywhere 122
# anything 121
# antique 120
# anti 119
# answer 118
# another 117
# anniversary 116
# ankle 115
# animal 114
# angle 113
# android 112
# and 111
# analog 110
# amp 109
# among 108
# american 107
# amazon 106
# amazing 105
# amaze 104
# always 103
# alter 102
# also 101
# along 100
# almost 99
# alloy 98
# allows 97
# allow 96
# allergic 95
# all 94
# align 93
# alarm 92
# airtight 91
# air 90
# age 89
# affordable 88
# aesthetic 87
# advisable 86
# advanced 85
# adult 84
# adorn 83
# adorable 82
# adjustable 81
# adjust 80
# adhesive 79
# additional 78
# addition 77
# adda 76
# add 75
# adapter 74
# actual 73
# activity 72
# active 71
# action 70
# act 69
# acrylic 68
# across 67
# acm 66
# acid 65
# achieve 64
# acer 63
# accurate 62
# accord 61
# accidental 60
# accessory 59
# accessories 58
# access 57
# abstract 56
# absorption 55
# absorb 54
# absolutely 53
# absolute 52
# able 51
# 99 50
# 92 49
# 80 48
# 75 47
# 65w 46
# 5v 45
# 5mm 44
# 5cm 43
# 50 42
# 4xl 41
# 4th 40
# 48 39
# 44 38
# 43 37
# 42 36
# 41 35
# 40 34
# 3xl 33
# 3d 32
# 39 31
# 38 30
# 37 29
# 36 28
# 35 27
# 34 26
# 33 25
# 32 24
# 31 23
# 30 22
# 2xl 21
# 29 20
# 28 19
# 27 18
# 26 17
# 25 16
# 24 15
# 23 14
# 22 13
# 20 12
# 19 11
# 18 10
# 17 9
# 16 8
# 15 7
# 14 6
# 13 5
# 12 4
# 11 3
# 100 2
# 10 1
# 00 0

# %%
# count vectorizer with different parameters
count_vec_2 = CountVectorizer(max_features = 2000, ngram_range = (1,2), max_df=0.95)
x_train_features_2 = count_vec_2.fit_transform(x_train)
x_test_features_2 = count_vec_2.transform(x_test)

# %%
train_data_1 = x_train_features_1.todense()
test_data_1 = x_test_features_1.todense()

# %%
train_data_2 = x_train_features_2.todense()
test_data_2 = x_test_features_2.todense()

# %%
f1 = np.array(count_vec_1.get_feature_names())
f2 = np.array(count_vec_2.get_feature_names())

# %%
# keeping features from second count vetoriser as the final features
f2 = f2[35:]
for ele in f2:
    print(ele)
# Out:
# 5mm
# 75
# 80
# 92
# able
# abstract
# access
# access button
# accessories
# accessory
# accord
# accurate
# acer
# achieve
# across
# acrylic
# action
# active
# activity
# actual
# actual product
# adapter
# add
# addition
# additional
# adhesive
# adjust
# adjustable
# adorable
# adorn
# advanced
# affordable
# age
# air
# air tight
# all
# allow
# allows
# alloy
# almost
# along
# also
# also use
# always
# amaze
# amazon
# american
# american diamond
# among
# amp
# analog
# and
# android
# angle
# animal
# ankle
# ankle length
# anniversary
# anniversary gift
# answer
# anti
# anti slip
# antique
# anything
# anywhere
# apparel
# appeal
# appearance
# apple
# apple watch
# application
# apply
# approx
# area
# around
# art
# art print
# artificial
# artisan
# artist
# artwork
# assure
# astrological
# asus
# attach
# attention
# attire
# attractive
# audio
# authentic
# auto
# auto detects
# automatically
# available
# available amazon
# avoid
# away
# awesome
# ayurvedic
# baby
# back
# back case
# back cover
# background
# backing
# backpack
# bag
# bag prevent
# bags
# balance
# balcony
# ball
# balloon
# balloons
# band
# bangle
# bangles
# bar
# base
# basic
# basis
# bass
# bathroom
# battery
# beach
# bead
# beads
# bear
# beautiful
# beautifully
# beauty
# become
# bed
# bed sheet
# bedroom
# bedsheet
# beige
# believe
# belt
# benefit
# best
# best gift
# best quality
# better
# beverage
# big
# bike
# bio
# birthday
# birthday anniversary
# birthday gift
# birthday party
# black
# bleach
# blend
# block
# blouse
# blouse piece
# blue
# bluetooth
# bmw
# board
# body
# body cover
# bold
# border
# bottle
# bottom
# box
# boy
# boyfriend
# boys
# bpa
# bpa free
# br
# br br
# bra
# bracelet
# brand
# brand name
# brand new
# brass
# break
# breathable
# bridal
# bright
# bring
# brings
# brother
# brown
# brush
# bubble
# buckle
# buddha
# built
# built in
# bulb
# bulk
# bump
# bumper
# business
# bust
# button
# buy
# buying
# cable
# call
# camera
# canvas
# canvas print
# cap
# capacity
# capri
# car
# car body
# car cover
# car seat
# carat
# carbon
# card
# card slot
# care
# care instruction
# care instructions
# carefully
# carpet
# carpets
# carry
# case
# case cover
# cases
# cash
# casual
# casual formal
# casual party
# casual shirt
# casual shoes
# casual wear
# category
# cause
# celebration
# cell
# center
# ceramic
# ceremony
# certificate
# certified
# chain
# chakra
# change
# charge
# charge fast
# charger
# charging
# charm
# chart
# check
# check size
# chemical
# chest
# chic
# chiffon
# child
# china
# chip
# choice
# choose
# christmas
# churidar
# circuit
# clarity
# clasp
# class
# classic
# classy
# clean
# clean cloth
# clean dry
# cleaning
# clear
# click
# climatic
# climatic condition
# clip
# clock
# close
# closure
# closure type
# cloth
# clothes
# clothing
# club
# cm
# coat
# coffee
# coffee mug
# coin
# cold
# cold water
# collar
# collection
# college
# color
# color black
# color blue
# color may
# color white
# colorful
# colors
# colour
# colour may
# colours
# combination
# combine
# combo
# combo pack
# come
# comes
# comfort
# comfort fit
# comfortable
# comfortable fit
# comfortable wear
# comfortably
# comfy
# compact
# companion
# company
# compare
# compartment
# compatibility
# compatible
# complement
# complete
# complete look
# completely
# compliment
# computer
# condition
# confidence
# connect
# connect device
# connection
# connector
# connectors
# consider
# construction
# contact
# contain
# container
# contains
# contemporary
# content
# contents
# contrast
# control
# convenience
# convenient
# cool
# copper
# cord
# core
# corner
# correct
# cost
# cotton
# cotton blend
# cotton fabric
# cotton lycra
# cotton shirt
# cotton style
# could
# could pair
# count
# couple
# cover
# cover case
# cover make
# coverage
# covers
# crack
# craft
# crafted
# craftsmanship
# cream
# create
# creates
# creation
# creations
# creative
# credit
# credit card
# crepe
# crop
# cross
# crowd
# crystal
# cubic
# cubic zirconia
# cup
# current
# current short
# curtain
# curtains
# curve
# cushion
# cushion cover
# custom
# customer
# customer service
# customize
# cut
# cute
# cutout
# cycle
# dad
# monitor
# monitor setting
# month
# months
# mother
# moto
# motorola
# mount
# mouth
# move
# movement
# mtr
# much
# mug
# mugs
# multi
# multi color
# multicolor
# multicolour
# multiple
# music
# must
# name
# natural
# naturally
# nature
# navy
# navy blue
# nbsp
# nbsp nbsp
# nbsp strong
# neck
# neck style
# neck type
# necklace
# necklace set
# need
# negative
# neo
# net
# never
# new
# next
# nice
# nickel
# nickel free
# night
# night suit
# nightwear
# nighty
# noise
# nokia
# non
# non toxic
# normal
# nose
# note
# note pro
# note redmi
# number
# nylon
# object
# occasion
# occasion casual
# occasions
# odorize
# odour
# off
# offer
# offering
# office
# office wear
# oil
# old
# on
# one
# one size
# online
# open
# opening
# operation
# oppo
# optimal
# option
# orange
# order
# organic
# original
# others
# out
# outdoor
# outer
# outer material
# outfit
# output
# outside
# outsole
# over
# over current
# overall
# pack
# package
# package contains
# package content
# package contents
# package include
# package includes
# packaging
# packed
# pad
# padded
# pain
# paint
# painting
# paintings
# pair
# pair jeans
# pair shoe
# pair stylish
# pajama
# palazzo
# panel
# pant
# pants
# paper
# part
# parts
# party
# party wear
# party wedding
# paste
# patiala
# pattern
# pattern solid
# pay
# pc
# pcs
# peace
# pearl
# peel
# pendant
# people
# per
# perfect
# perfect everyday
# perfect fit
# perfect fitting
# perfect gift
# perfection
# perfectly
# performance
# perfume
# period
# person
# personal
# personality
# personalize
# phone
# photo
# photographic
# photographic light
# photography
# physical
# pick
# picture
# piece
# pieces
# pillow
# pillow cover
# pillow covers
# pin
# pink
# place
# place order
# plain
# planet
# plant
# planter
# plastic
# plat
# plated
# play
# please
# please check
# please contact
# please note
# please refer
# plug
# plus
# plus size
# plush
# pocket
# pockets
# point
# polish
# polo
# poly
# polycarbonate
# polyester
# polyester fabric
# pooja
# popular
# port
# portable
# position
# positive
# possible
# poster
# pot
# pouch
# powder
# power
# powerful
# pre
# precious
# precise
# precision
# prefer
# premium
# premium quality
# present
# presents
# press
# pressure
# pretty
# prevent
# prevent stain
# prevents
# price
# prime
# princess
# print
# printed
# printing
# printing technology
# prints
# pro
# pro redmi
# problem
# process
# produce
# product
# product color
# product colour
# product description
# product image
# product make
# product may
# production
# products
# professional
# promise
# proof
# proper
# property
# protect
# protect device
# protection
# protective
# protector
# protects
# protects vehicle
# provide
# provide best
# provides
# pull
# purchase
# pure
# pure cotton
# purple
# purpose
# purse
# push
# put
# pvc
# pyjama
# pyjama set
# quality
# quality cotton
# quality fabric
# quality material
# quality product
# quantity
# quartz
# question
# quick
# rain
# range
# rate
# ratti
# raw
# ray
# rayon
# re
# reach
# read
# ready
# readymade
# real
# really
# rear
# reason
# receive
# recommend
# recommended
# red
# redmi
# redmi note
# redmi pro
# redmi redmi
# reduce
# refer
# reference
# reflect
# refresh
# regular
# regular fit
# reinforce
# relaxed
# release
# reliable
# remain
# remains
# remote
# remote control
# removable
# removal
# remove
# replace
# replacement
# represent
# require
# requirement
# residue
# resistance
# resistant
# resists
# resolution
# response
# rest
# result
# retail
# retain
# return
# reusable
# rich
# today
# toe
# together
# tone
# tool
# top
# tops
# total
# touch
# tough
# toxic
# toy
# toys
# tpu
# track
# track pant
# trade
# traditional
# transfer
# transparent
# travel
# treat
# trend
# trendy
# trim
# triple
# trouser
# trousers
# trousers complete
# true
# trust
# try
# tshirt
# tshirts
# tube
# tumble
# tumble dry
# turn
# two
# two wheeler
# type
# type half
# type regular
# uk
# ul
# ultimate
# ultra
# understand
# unique
# unique design
# unisex
# unit
# universal
# unstitched
# up
# upgrade
# upper
# upto
# us
# usa
# usage
# usb
# usb cable
# use
# use clean
# use could
# use shoe
# used
# useful
# user
# using
# usually
# vacuum
# valentine
# valentine day
# value
# variation
# variety
# various
# vary
# vary due
# vehicle
# velvet
# versatile
# version
# via
# vibrant
# video
# view
# vintage
# vinyl
# vivid
# vivo
# voice
# voltage
# volume
# waist
# waist inch
# waist size
# waistband
# walk
# wall
# wall art
# wall charger
# wall clock
# wallet
# wallpaper
# want
# wardrobe
# warm
# warranty
# warranty manufacturing
# wash
# wash care
# wash cold
# wash machine
# wash separately
# washable
# washed
# washing
# watch
# watch series
# water
# water bottle
# water resistant
# waterproof
# way
# we
# wear
# wear party
# wearer
# wearing
# weather
# weave
# wedding
# weight
# welcome
# well
# western
# wet
# wheel
# wheeler
# wherever
# whether
# white
# whole
# wide
# wide range
# width
# wife
# window
# winter
# wipe
# wire
# wired
# wireless
# wish
# within
# without
# woman
# woman girl
# women
# women cotton
# women girls
# womens
# wonderful
# wood
# wooden
# wool
# work
# workout
# world
# worn
# worry
# would
# woven
# wrap
# wrinkle
# wrist
# write
# xiaomi
# xiaomi redmi
# xl
# xxl
# year
# year warranty
# years
# yellow
# yellow sapphire
# yet
# yoga
# you
# young
# youth
# zip
# zipper
# zirconia

# %%
df_train_2 = pd.DataFrame(data = train_data_2, columns= f2) # saving the data for further use 
df_train_2.to_csv('df_train_2.csv', index = False)
df_test_2 = pd.DataFrame(data = test_data_2, columns= f2)
df_test_2.to_csv('df_test_2.csv', index = False)
np.savetxt('train_data_1.csv', train_data_1, delimiter = ",")
np.savetxt('train_data_2.csv', train_data_2, delimiter = ",")
np.savetxt('test_data_1.csv', test_data_1, delimiter = ",")
np.savetxt('test_data_2.csv', test_data_2, delimiter = ',')
# np.savetxt('f1.csv', f1, delimiter = ",", fmt = '%s')
np.savetxt('f2.csv', f2, delimiter = ",", fmt = '%s')
y_train = np.array(y_train)
y_test = np.array(y_test)
np.savetxt('y_train.csv', y_train, delimiter = ",")
np.savetxt('y_test.csv', y_test, delimiter = ',')

# %% [markdown]
# ## DATA VISUALISATION

# %%
from wordcloud import WordCloud

# %%
x_train = pd.read_csv('df_train_2.csv') # reading the x_train
y_train = pd.read_csv('y_train.csv', header = None) # reading the y_train
y_train = np.array(list(y_train[0].values))
y_train = np.array(y_train, dtype = int)

# %%
sum_words = x_train.sum(axis=0) 
features = np.array(list(sum_words.keys())) # storing the features 
count = np.array(list(sum_words.values)) # storing the count of features

# %%
order = np.argsort(count)[::-1]
features = features[order] # sorting in descending order
# every occasion 938
# access button 937
# credit card 937
# style round 937
# material make 937
# sleeve length 937
# wall decor 936
# easy wear 936
# nose 936
# style regular 936
# seamless 936
# cozy 934
# look stylish 934
# voice 934
# wired 933
# shield 933
# board 933
# party wedding 932
# slide 930
# element 929
# wealth 928
# anything 928
# dry low 928
# no 927
# shirt men 927
# rings 927
# neck type 926
# operation 926
# tablets 925
# strong product 923
# helps 922
# latex 922
# joy 921
# factory 921
# flow 921
# curve 920
# hall 919
# comfortable fit 919
# purse 919
# explore 919
# group 917
# lighting 917
# forever 917
# settings 915
# product image 914
# maintenance 912
# package includes 910
# graceful 907
# treatment 907
# understand 905
# extract 904
# design give 904
# mala 903
# disclaimer product 902
# raw 902
# canvas print 901
# also use 901
# hstnn 900
# set women 899
# material type 899
# reflect 899
# strip 898
# black white 898
# ios 898
# paintings 897
# skinny 897
# via 893
# moment 892
# technique 892
# mention 892
# material plastic 891
# back side 889
# dad 888
# edition 888
# ready hang 888
# polished 887
# sparkle 887
# face mask 887
# cubic zirconia 887
# plating 886
# individual 886
# formula 886
# highly durable 885
# shoulder strap 885
# gadgets 885
# last long 884
# material high 884
# buttons 884
# slightly different 884
# stripe 883
# flops 883
# rough 883
# specific 882
# foil balloon 881
# bird 881
# making 881
# faster 881
# tunic 880
# easy apply 879
# mild detergent 879
# growth 879
# wall painting 879
# flip flops 878
# airtight 878
# cotton shirt 878
# makeup 877
# humid 876
# selection 876
# marriage 875
# lead free 874
# rudraksha 874
# design provide 872
# realme 872
# bedsheet pillow 871
# look great 871
# woman girl 871
# loafers 870
# conditions 870

# %%
dict_words = {} # adding words and their frequency in a dictionary
for i in range(len(features)):
    dict_words[features[i]] = count[i]
dict_words
# Out:
# {'size': 61276,
#  'quality': 59717,
#  'make': 57553,
#  'design': 53433,
#  'material': 51706,
#  'use': 49465,
#  'product': 45180,
#  'wear': 42723,
#  'color': 41982,
#  'high': 40450,
#  'cotton': 40056,
#  'look': 39643,
#  'cover': 38784,
#  'fit': 36140,
#  'strong': 34684,
#  'perfect': 33951,
#  'fabric': 32480,
#  'style': 31394,
#  'women': 31084,
#  'men': 30003,
#  'gift': 29928,
#  'inch': 29240,
#  'easy': 28545,
#  'soft': 26742,
#  'casual': 26094,
#  'type': 25633,
#  'wash': 25507,
#  'length': 25005,
#  'long': 23473,
#  'skin': 23196,
#  'water': 23078,
#  'leather': 23012,
#  'set': 22818,
#  'one': 22807,
#  'high quality': 22058,
#  'case': 21851,
#  'free': 21611,
#  'print': 21536,
#  'comfortable': 21367,
#  'best': 21117,
#  'black': 20825,
#  'stylish': 20749,
#  'wall': 20361,
#  'shirt': 20205,
#  'day': 20085,
#  'light': 20078,
#  'give': 20060,
#  'li': 19744,
#  'woman': 19597,
#  'dress': 19334,
#  'comfort': 18814,
#  'phone': 18522,
#  'home': 18257,
#  'also': 18235,
#  'provide': 18141,
#  'fashion': 17870,
#  'party': 17838,
#  'made': 17823,
#  'back': 17795,
#  'pair': 17324,
#  'please': 17152,
#  'colour': 17096,
#  'care': 16937,
#  'shoe': 16900,
#  'top': 16658,
#  'dry': 16568,
#  'keep': 16326,
#  'occasion': 15820,
#  'premium': 15736,
#  'time': 15723,
#  'sleeve': 15564,
#  'brand': 15413,
#  'device': 15303,
#  'hand': 15210,
#  'protection': 15094,
#  'durable': 14765,
#  'battery': 14538,
#  'clean': 14495,
#  'charge': 14305,
#  'laptop': 14288,
#  'full': 14094,
#  'room': 13891,
#  'well': 13764,
#  'get': 13715,
#  'white': 13688,
#  'car': 13595,
#  'good': 13585,
#  'beautiful': 13526,
#  'blue': 13428,
#  'new': 13322,
#  'great': 13297,
#  'like': 13249,
#  'feel': 12997,
#  'printed': 12959,
#  'note': 12934,
#  'bag': 12575,
#  'body': 12568,
#  'nbsp': 12536,
#  'love': 12420,
#  'work': 12410,
#  'package': 12391,
#  'weight': 12241,
#  'watch': 12043,
#  'come': 12033,
#  'resistant': 11799,
#  'neck': 11789,
#  'art': 11719,
#  'screen': 11708,
#  'regular': 11692,
#  'may': 11563,
#  'feature': 11514,
#  'silver': 11427,
#  'mobile': 11407,
#  'glass': 11169,
#  'piece': 11121,
#  'redmi': 11101,
#  'charger': 11100,
#  'gold': 11086,
#  'waist': 10978,
#  'add': 10952,
#  'range': 10902,
#  'pack': 10880,
#  'finish': 10861,
#  'jewellery': 10848,
#  'unique': 10678,
#  'pocket': 10665,
#  'without': 10633,
#  'office': 10626,
#  'collection': 10514,
#  'side': 10440,
#  'br': 10408,
#  'available': 10392,
#  'item': 10344,
#  'protect': 10322,
#  'life': 10248,
#  'compatible': 10228,
#  'round': 10103,
#  'pattern': 10076,
#  'every': 10047,
#  'suitable': 9963,
#  'natural': 9926,
#  'bottle': 9855,
#  'girls': 9750,
#  'india': 9640,
#  'need': 9576,
#  'ring': 9565,
#  'ideal': 9485,
#  'galaxy': 9483,
#  'help': 9426,
#  'surface': 9352,
#  'dust': 9315,
#  'birthday': 9255,
#  'scratch': 9198,
#  'special': 9150,
#  'closure': 9115,
#  'stone': 8986,
#  'red': 8980,
#  'girl': 8950,
#  'include': 8948,
#  'large': 8909,
#  'wide': 8846,
#  'short': 8796,
#  'canvas': 8726,
#  'remove': 8692,
#  'safe': 8687,
#  'machine': 8682,
#  'different': 8679,
#  'etc': 8675,
#  'foot': 8657,
#  'anti': 8651,
#  'kurta': 8649,
#  'warranty': 8575,
#  'power': 8542,
#  'smart': 8501,
#  'belt': 8458,
#  'due': 8389,
#  'elegant': 8271,
#  'wallpaper': 8170,
#  'take': 8168,
#  'year': 8168,
#  'store': 8102,
#  'daily': 7976,
#  'card': 7954,
#  'offer': 7938,
#  'original': 7908,
#  'touch': 7900,
#  'complete': 7880,
#  'shape': 7865,
#  'designer': 7801,
#  'plastic': 7757,
#  'line': 7751,
#  'painting': 7741,
#  'frame': 7690,
#  'button': 7682,
#  'wedding': 7637,
#  'non': 7620,
#  'lightweight': 7563,
#  'trendy': 7518,
#  'shoes': 7489,
#  'metal': 7465,
#  'strap': 7462,
#  'customer': 7443,
#  'slim': 7425,
#  'saree': 7416,
#  'friendly': 7398,
#  'traditional': 7390,
#  'wallet': 7363,
#  'silk': 7340,
#  'solid': 7324,
#  'air': 7277,
#  'small': 7249,
#  'suit': 7237,
#  'last': 7236,
#  'pure': 7229,
#  'blouse': 7229,
#  'smooth': 7193,
#  'polyester': 7177,
#  'usb': 7072,
#  'indian': 7062,
#  'sole': 7060,
#  'ensure': 7059,
#  'house': 7044,
#  'cloth': 7015,
#  'jewelry': 7014,
#  'in': 6964,
#  'slip': 6952,
#  'two': 6848,
#  'seat': 6806,
#  'box': 6791,
#  'model': 6750,
#  'even': 6740,
#  'steel': 6687,
#  'image': 6619,
#  'fine': 6602,
#  'cold': 6590,
#  'super': 6579,
#  'front': 6576,
#  'carry': 6547,
#  'instructions': 6545,
#  'place': 6540,
#  'sticker': 6487,
#  'cushion': 6482,
#  'order': 6472,
#  'night': 6464,
#  'decor': 6433,
#  'proof': 6330,
#  'technology': 6324,
#  'living': 6301,
#  'flip': 6286,
#  'gemstone': 6263,
#  'green': 6247,
#  'ethnic': 6222,
#  'stand': 6221,
#  'formal': 6194,
#  'genuine': 6184,
#  'pant': 6151,
#  'pro': 6074,
#  'support': 6031,
#  'light weight': 6021,
#  'easily': 6010,
#  'features': 6004,
#  'cut': 5988,
#  'earring': 5956,
#  'multi': 5952,
#  'inches': 5937,
#  'clock': 5919,
#  'plus': 5902,
#  'attractive': 5898,
#  'friend': 5889,
#  'adapter': 5883,
#  'damage': 5873,
#  'mug': 5818,
#  'pink': 5783,
#  'hair': 5742,
#  'cable': 5730,
#  'vehicle': 5728,
#  'extra': 5728,
#  'classic': 5718,
#  'name': 5684,
#  'amazon': 5681,
#  'cool': 5674,
#  'call': 5629,
#  'match': 5620,
#  'contact': 5620,
#  'necklace': 5615,
#  'footwear': 5585,
#  'skirt': 5548,
#  'sure': 5518,
#  'waterproof': 5506,
#  'designed': 5490,
#  'bottom': 5485,
#  'brown': 5462,
#  'show': 5460,
#  'control': 5446,
#  'way': 5407,
#  'regular fit': 5355,
#  'care instructions': 5332,
#  'stainless': 5326,
#  'durability': 5321,
#  'yellow': 5298,
#  'modern': 5296,
#  'synthetic': 5295,
#  'jacket': 5283,
#  'vary': 5273,
#  'sport': 5270,
#  'stitch': 5256,
#  'width': 5253,
#  'everyday': 5252,
#  'choice': 5238,
#  'double': 5236,
#  'sound': 5220,
#  'function': 5217,
#  'ultra': 5207,
#  'stainless steel': 5202,
#  'accessory': 5193,
#  'travel': 5169,
#  'half': 5167,
#  'check': 5166,
#  'decoration': 5148,
#  'part': 5135,
#  'living room': 5133,
#  'band': 5132,
#  'combo': 5119,
#  'family': 5119,
#  'oil': 5100,
#  'samsung': 5084,
#  'bedroom': 5081,
#  'machine wash': 5081,
#  'premium quality': 5078,
#  'tablet': 5071,
#  'want': 5069,
#  'slightly': 5046,
#  'dupatta': 5045,
#  'balloon': 5011,
#  'craft': 4997,
#  'buy': 4972,
#  'paper': 4968,
#  'carpet': 4944,
#  'elastic': 4943,
#  'outdoor': 4943,
#  'jeans': 4936,
#  'vinyl': 4930,
#  'apply': 4905,
#  'fast': 4891,
#  'picture': 4887,
#  'protects': 4884,
#  'adjustable': 4866,
#  'late': 4853,
#  'let': 4850,
#  'per': 4836,
#  'away': 4831,
#  'matte': 4815,
#  'jean': 4804,
#  'choose': 4801,
#  'bluetooth': 4797,
#  'shoulder': 4786,
#  'inside': 4786,
#  'allow': 4769,
#  'experience': 4763,
#  'ear': 4748,
#  'baby': 4739,
#  'outfit': 4729,
#  'display': 4716,
#  'fashionable': 4711,
#  'camera': 4708,
#  'kid': 4683,
#  'rich': 4670,
#  'pendant': 4668,
#  'edge': 4641,
#  'hard': 4635,
#  'eye': 4634,
#  'height': 4576,
#  'low': 4575,
#  'anniversary': 4575,
#  'redmi redmi': 4569,
#  'denim': 4558,
#  'curtain': 4546,
#  'performance': 4538,
#  'face': 4537,
#  'world': 4516,
#  'bleach': 4505,
#  'hang': 4486,
#  'medium': 4478,
#  'must': 4463,
#  'season': 4451,
#  'lace': 4445,
#  'built': 4439,
#  'excellent': 4437,
#  'bracelet': 4436,
#  'number': 4432,
#  'bust': 4418,
#  'fitting': 4397,
#  'little': 4389,
#  'layer': 4376,
#  'grade': 4371,
#  'buckle': 4370,
#  'hand wash': 4365,
#  'access': 4365,
#  'beauty': 4312,
#  'monitor': 4310,
#  'worn': 4289,
#  'printing': 4284,
#  'inner': 4282,
#  'measurement': 4276,
#  'shop': 4267,
#  'round neck': 4257,
#  'soap': 4236,
#  'protector': 4232,
#  'copper': 4231,
#  'heel': 4222,
#  'amp': 4213,
#  'price': 4211,
#  'exclusive': 4209,
#  'heat': 4207,
#  'summer': 4203,
#  'the': 4198,
#  'around': 4195,
#  'hour': 4193,
#  'chest': 4188,
#  'covers': 4186,
#  'party wear': 4178,
#  'actual': 4151,
#  'poster': 4142,
#  'create': 4138,
#  'avoid': 4137,
#  'clear': 4128,
#  'know': 4112,
#  'quality material': 4101,
#  'ready': 4086,
#  'enhance': 4084,
#  'speed': 4075,
#  'handmade': 4066,
#  'wide range': 4063,
#  'allows': 4061,
#  'music': 4059,
#  'water resistant': 4050,
#  'dirt': 4049,
#  'ensures': 4031,
#  'iron': 4017,
#  'effect': 4005,
#  'pillow': 4004,
#  'bed': 4001,
#  'chart': 3991,
#  'warm': 3984,
#  'standard': 3984,
#  'install': 3970,
#  'many': 3956,
#  'mask': 3945,
#  'mirror': 3941,
#  'team': 3930,
#  'replacement': 3912,
#  'superior': 3911,
#  'first': 3910,
#  'fabric cotton': 3901,
#  'put': 3881,
#  'condition': 3879,
#  'hot': 3878,
#  'base': 3878,
#  'seller': 3870,
#  'wrap': 3863,
#  'body cover': 3857,
#  'safety': 3855,
#  'coffee': 3851,
#  'wash care': 3830,
#  'bring': 3822,
#  'grey': 3799,
#  'capacity': 3794,
#  'rubber': 3794,
#  'detail': 3788,
#  'temperature': 3783,
#  'find': 3772,
#  'sleeves': 3756,
#  'right': 3754,
#  'simple': 3753,
#  'normal': 3753,
#  'crystal': 3749,
#  'bra': 3743,
#  'shade': 3738,
#  'series': 3731,
#  'never': 3724,
#  'slipper': 3707,
#  'earrings': 3702,
#  'perfect gift': 3701,
#  'purpose': 3684,
#  'kitchen': 3675,
#  'size chart': 3671,
#  'pot': 3666,
#  'products': 3658,
#  'zip': 3638,
#  'prevent': 3615,
#  'slim fit': 3611,
#  'kids': 3610,
#  'stretchable': 3609,
#  'plated': 3608,
#  'photo': 3607,
#  'seat cover': 3600,
#  'storage': 3597,
#  'highly': 3596,
#  'wardrobe': 3577,
#  'present': 3573,
#  'blend': 3565,
#  'ul': 3556,
#  'casual wear': 3550,
#  'outer': 3532,
#  'flower': 3505,
#  'grip': 3503,
#  'charging': 3489,
#  'food': 3485,
#  'interior': 3469,
#  'perfectly': 3467,
#  'breathable': 3466,
#  'instruction': 3456,
#  'would': 3444,
#  'plant': 3437,
#  'this': 3436,
#  'zipper': 3433,
#  'service': 3430,
#  'valentine': 3425,
#  'thread': 3422,
#  'brings': 3421,
#  'stretch': 3412,
#  'open': 3409,
#  'trend': 3407,
#  'dark': 3403,
#  'coat': 3403,
#  'port': 3401,
#  'bike': 3401,
#  'gifts': 3398,
#  'digital': 3369,
#  'free size': 3363,
#  'micro': 3363,
#  'colors': 3343,
#  'self': 3339,
#  'quick': 3339,
#  'enjoy': 3337,
#  'apple': 3331,
#  'ceramic': 3330,
#  'hold': 3326,
#  'content': 3323,
#  'sleep': 3322,
#  'water bottle': 3315,
#  'connect': 3313,
#  'real': 3296,
#  'adhesive': 3294,
#  'sports': 3293,
#  'diamond': 3292,
#  'comes': 3289,
#  'single': 3279,
#  'led': 3278,
#  'see': 3273,
#  'always': 3271,
#  'weather': 3268,
#  'run': 3243,
#  'upper': 3238,
#  'li ul': 3232,
#  'flat': 3230,
#  'lycra': 3227,
#  'it': 3221,
#  'pockets': 3220,
#  'sheet': 3220,
#  'lip': 3211,
#  're': 3207,
#  'moisture': 3206,
#  'walk': 3201,
#  'samsung galaxy': 3199,
#  'wall clock': 3195,
#  'perfect fit': 3194,
#  'certified': 3188,
#  'much': 3187,
#  'ipad': 3181,
#  'cute': 3176,
#  'stick': 3173,
#  'stay': 3160,
#  'salwar': 3150,
#  'floral': 3149,
#  'big': 3145,
#  'loose': 3138,
#  'sandal': 3137,
#  'space': 3136,
#  'collar': 3136,
#  'heavy': 3132,
#  'manufacturing': 3131,
#  'age': 3128,
#  'compartment': 3118,
#  'container': 3117,
#  'deliver': 3115,
#  'rise': 3105,
#  'years': 3100,
#  'material cotton': 3091,
#  'dimension': 3090,
#  'washable': 3089,
#  'laptop skin': 3085,
#  'easy install': 3073,
#  'complete look': 3072,
#  'back cover': 3071,
#  'installation': 3071,
#  'lifestyle': 3069,
#  'lead': 3064,
#  'golden': 3061,
#  'could': 3048,
#  'may slightly': 3043,
#  'best quality': 3041,
#  'kind': 3039,
#  'make high': 3033,
#  'decorative': 3030,
#  'energy': 3026,
#  'paint': 3020,
#  'maintain': 3006,
#  'play': 3005,
#  'classy': 3002,
#  'lasting': 2995,
#  'heart': 2994,
#  'contents': 2993,
#  'mobile phone': 2983,
#  'door': 2976,
#  'panel': 2975,
#  'extremely': 2972,
#  'strength': 2971,
#  'decal': 2963,
#  'backpack': 2948,
#  'palazzo': 2941,
#  'bedsheet': 2939,
#  'boys': 2927,
#  'description': 2925,
#  'packaging': 2924,
#  'option': 2923,
#  'maximum': 2902,
#  'accessories': 2902,
#  'dial': 2899,
#  'redmi note': 2899,
#  'comfortable wear': 2896,
#  'sun': 2892,
#  'mini': 2891,
#  'shampoo': 2891,
#  'sterling': 2891,
#  'xiaomi': 2884,
#  'size inch': 2873,
#  'value': 2871,
#  'texture': 2864,
#  'stain': 2854,
#  'indoor': 2853,
#  'over': 2853,
#  'wood': 2845,
#  'fade': 2837,
#  'specially': 2835,
#  'along': 2835,
#  'long lasting': 2832,
#  'skin friendly': 2829,
#  'women girls': 2829,
#  'people': 2826,
#  'go': 2823,
#  'chain': 2823,
#  'on': 2822,
#  'used': 2818,
#  'christmas': 2813,
#  'festive': 2812,
#  'leave': 2811,
#  'feet': 2803,
#  'good quality': 2801,
#  'half sleeve': 2799,
#  'plug': 2797,
#  'handle': 2797,
#  'gym': 2794,
#  'legging': 2793,
#  'combination': 2790,
#  'current': 2789,
#  'sterling silver': 2788,
#  'cotton fabric': 2788,
#  'home office': 2787,
#  'cushion cover': 2786,
#  'love one': 2784,
#  'lid': 2778,
#  'screen protector': 2776,
#  'variety': 2774,
#  'dimensions': 2759,
#  'remote': 2758,
#  'lipstick': 2747,
#  'easy clean': 2746,
#  'guarantee': 2741,
#  'health': 2736,
#  'charm': 2725,
#  'quality product': 2719,
#  'child': 2710,
#  'drop': 2705,
#  'daily wear': 2705,
#  'area': 2697,
#  'tight': 2697,
#  'genuine leather': 2693,
#  'essential': 2688,
#  'shock': 2688,
#  'lens': 2685,
#  'mind': 2675,
#  'compatibility': 2675,
#  'brass': 2670,
#  'shirts': 2660,
#  'long last': 2657,
#  'pyjama': 2655,
#  'window': 2653,
#  'diameter': 2644,
#  'multiple': 2643,
#  'favorite': 2634,
#  'handbag': 2629,
#  'require': 2628,
#  'toe': 2627,
#  'boy': 2617,
#  'fully': 2610,
#  'purchase': 2602,
#  'nightwear': 2599,
#  'movement': 2596,
#  'contains': 2595,
#  'plain': 2589,
#  'jar': 2584,
#  'cup': 2584,
#  'flexible': 2582,
#  'earphone': 2580,
#  'business': 2575,
#  'step': 2570,
#  'head': 2563,
#  'custom': 2549,
#  'usage': 2541,
#  'dry clean': 2539,
#  'length inch': 2537,
#  'polo': 2537,
#  'problem': 2531,
#  'convenient': 2529,
#  'men women': 2528,
#  'disclaimer': 2517,
#  'pad': 2514,
#  'slot': 2513,
#  'auto': 2510,
#  'everyday use': 2508,
#  'manufacturer': 2507,
#  'wall charger': 2504,
#  'gold plated': 2500,
#  'voltage': 2498,
#  'sneaker': 2496,
#  'wireless': 2495,
#  'gentle': 2492,
#  'luxury': 2486,
#  'fresh': 2482,
#  'cold water': 2480,
#  'smartphone': 2477,
#  'built in': 2475,
#  'statement': 2475,
#  'iphone': 2470,
#  'ankle': 2469,
#  'meter': 2467,
#  'headphone': 2464,
#  'android': 2461,
#  'sling': 2457,
#  'form': 2444,
#  'select': 2444,
#  'pants': 2443,
#  'yet': 2439,
#  'alloy': 2435,
#  'wooden': 2430,
#  'nbsp nbsp': 2428,
#  'kurti': 2427,
#  'inch inch': 2426,
#  'toy': 2426,
#  'separately': 2422,
#  'chemical': 2418,
#  'bangle': 2418,
#  'package contents': 2418,
#  'source': 2417,
#  'bass': 2416,
#  'setting': 2412,
#  'money': 2412,
#  'worry': 2411,
#  'sell': 2409,
#  'sturdy': 2409,
#  'process': 2407,
#  'liquid': 2407,
#  'mother': 2406,
#  'bubble': 2403,
#  'slightly vary': 2402,
#  'sapphire': 2399,
#  'dual': 2397,
#  'happy': 2396,
#  'pearl': 2394,
#  'care instruction': 2392,
#  'photographic': 2391,
#  'transparent': 2386,
#  'peel': 2385,
#  'brand new': 2379,
#  'residue': 2367,
#  'shop wide': 2363,
#  'lock': 2361,
#  'recommend': 2360,
#  'wet': 2359,
#  'silicone': 2350,
#  'vibrant': 2349,
#  'pouch': 2349,
#  'sleeve type': 2347,
#  'holder': 2347,
#  'true': 2342,
#  'imported': 2339,
#  'approx': 2334,
#  'royal': 2331,
#  'gsm': 2322,
#  'sizes': 2320,
#  'three': 2315,
#  'thin': 2308,
#  'deep': 2305,
#  'xxl': 2303,
#  'bright': 2302,
#  'shipping': 2297,
#  'mens': 2289,
#  'turn': 2289,
#  'western': 2282,
#  'winter': 2282,
#  'rayon': 2281,
#  'end': 2277,
#  'festival': 2276,
#  'multicolor': 2275,
#  'return': 2271,
#  'track': 2271,
#  'bar': 2270,
#  'detergent': 2270,
#  'shopping': 2265,
#  'message': 2264,
#  'important': 2263,
#  'knee': 2254,
#  'cleaning': 2245,
#  'tempered': 2243,
#  'vary due': 2237,
#  'parts': 2231,
#  'unisex': 2230,
#  'up': 2228,
#  'plat': 2223,
#  'simply': 2222,
#  'orange': 2217,
#  'wash cold': 2209,
#  'included': 2207,
#  'speaker': 2207,
#  'slippers': 2206,
#  'search': 2205,
#  'view': 2202,
#  'due photographic': 2199,
#  'headset': 2198,
#  'occasions': 2196,
#  'shine': 2195,
#  'womens': 2189,
#  'nbsp strong': 2188,
#  'earbuds': 2184,
#  'satin': 2184,
#  'latest': 2182,
#  'possible': 2179,
#  'online': 2177,
#  'crafted': 2177,
#  'compact': 2176,
#  'fit type': 2171,
#  'designs': 2169,
#  'coverage': 2169,
#  'ultimate': 2168,
#  'powerful': 2166,
#  'international': 2163,
#  'lenovo': 2161,
#  'completely': 2160,
#  'nice': 2158,
#  'difference': 2156,
#  'tshirt': 2156,
#  'made india': 2153,
#  'beach': 2153,
#  'women cotton': 2150,
#  'perfume': 2149,
#  'may vary': 2146,
#  'padded': 2139,
#  'class': 2138,
#  'wife': 2138,
#  'strong strong': 2138,
#  'fancy': 2137,
#  'closure type': 2133,
#  'various': 2133,
#  'sweat': 2132,
#  'made high': 2129,
#  'leggings': 2128,
#  'less': 2126,
#  'enough': 2126,
#  'beautifully': 2123,
#  'color may': 2122,
#  'pvc': 2120,
#  'sunglass': 2120,
#  'magnetic': 2115,
#  'day long': 2114,
#  'straight': 2112,
#  'key': 2098,
#  'tempered glass': 2095,
#  'occasion casual': 2087,
#  'home decor': 2084,
#  'fiber': 2084,
#  'thickness': 2082,
#  'shorts': 2079,
#  'receive': 2075,
#  'question': 2072,
#  'girlfriend': 2071,
#  'data': 2070,
#  'american': 2068,
#  'professional': 2068,
#  'fall': 2068,
#  'appearance': 2065,
#  'application': 2062,
#  'elegance': 2060,
#  'flop': 2060,
#  'vivo': 2059,
#  'artwork': 2059,
#  'impact': 2059,
#  'import': 2056,
#  'tab': 2053,
#  'quartz': 2052,
#  'embroidery': 2048,
#  'eco': 2047,
#  'cell': 2046,
#  'delivery': 2039,
#  'block': 2035,
#  'great gift': 2035,
#  'make sure': 2034,
#  'flip flop': 2034,
#  'school': 2030,
#  'br br': 2030,
#  'appeal': 2027,
#  'level': 2027,
#  'sleek': 2023,
#  'film': 2019,
#  'wipe': 2018,
#  'max': 2017,
#  'net': 2017,
#  'universal': 2016,
#  'satisfaction': 2013,
#  'case cover': 2007,
#  'nighty': 2005,
#  'measure': 2001,
#  'tea': 2000,
#  'yoga': 1998,
#  'navy': 1997,
#  'fold': 1996,
#  'mild': 1996,
#  'longer': 1995,
#  'secure': 1995,
#  'room bedroom': 1987,
#  'tumble': 1986,
#  'easy access': 1985,
#  'powder': 1984,
#  'mesh': 1981,
#  'connector': 1979,
#  'carefully': 1979,
#  'thick': 1978,
#  'woven': 1977,
#  'unit': 1976,
#  'package content': 1974,
#  'amaze': 1973,
#  'direct': 1973,
#  'color black': 1973,
#  'stitched': 1970,
#  'change': 1967,
#  'construction': 1965,
#  'decorate': 1964,
#  'finger': 1961,
#  'fits': 1961,
#  'clothing': 1960,
#  'drive': 1951,
#  'protective': 1948,
#  'activity': 1944,
#  'please note': 1942,
#  'gorgeous': 1940,
#  'reduce': 1935,
#  'wrist': 1930,
#  'extreme': 1926,
#  'us': 1923,
#  'vintage': 1921,
#  'mid': 1917,
#  'bear': 1915,
#  'increase': 1914,
#  'running': 1914,
#  'pair stylish': 1913,
#  'months': 1911,
#  'figure': 1911,
#  'precise': 1909,
#  'jewels': 1905,
#  'ease': 1904,
#  'synthetic leather': 1903,
#  'cap': 1901,
#  'sister': 1899,
#  'look fabric': 1896,
#  'sleeveless': 1889,
#  'main': 1889,
#  'long sleeve': 1885,
#  'output': 1883,
#  'car cover': 1881,
#  'degree': 1876,
#  'logo': 1875,
#  'test': 1875,
#  'lady': 1868,
#  'circuit': 1864,
#  'pure cotton': 1856,
#  'tumble dry': 1853,
#  'contemporary': 1853,
#  'month': 1851,
#  'fun': 1851,
#  'ray': 1848,
#  ...}

# %%
# a wordcliud to visualize most frequent features
wordcloud = WordCloud(width=3000, height = 3000, max_words = 500)
wordcloud.generate_from_frequencies(dict_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('wordcloud.png')
plt.show()

# %%
# count of top 20 words
plt.bar(features[0:20], count[0:20])
plt.xticks(rotation = 90)
plt.title("TOP 20 WORDS")
plt.xlabel("WORDS")
plt.ylabel("COUNT")
plt.savefig('topWords.png')
plt.show()

# %%
bi_grams = [] # obtaining top bigrams
bi_grams_count = []
for i in range(len(features)):
    words = features[i].split()
    if(len(words) == 2):
        bi_grams.append(" ".join(words))
        bi_grams_count.append(count[i])
for i in range(len(bi_grams)):
    print(bi_grams[i], bi_grams_count[i])
# Out:
# high quality 22058
# light weight 6021
# regular fit 5355
# care instructions 5332
# stainless steel 5202
# living room 5133
# machine wash 5081
# premium quality 5078
# redmi redmi 4569
# hand wash 4365
# round neck 4257
# party wear 4178
# quality material 4101
# wide range 4063
# water resistant 4050
# fabric cotton 3901
# body cover 3857
# wash care 3830
# perfect gift 3701
# size chart 3671
# slim fit 3611
# seat cover 3600
# casual wear 3550
# free size 3363
# water bottle 3315
# li ul 3232
# samsung galaxy 3199
# wall clock 3195
# perfect fit 3194
# material cotton 3091
# laptop skin 3085
# easy install 3073
# complete look 3072
# back cover 3071
# may slightly 3043
# best quality 3041
# make high 3033
# mobile phone 2983
# redmi note 2899
# comfortable wear 2896
# size inch 2873
# long lasting 2832
# skin friendly 2829
# women girls 2829
# good quality 2801
# half sleeve 2799
# sterling silver 2788
# cotton fabric 2788
# home office 2787
# cushion cover 2786
# love one 2784
# screen protector 2776
# easy clean 2746
# quality product 2719
# daily wear 2705
# genuine leather 2693
# long last 2657
# dry clean 2539
# length inch 2537
# men women 2528
# everyday use 2508
# wall charger 2504
# gold plated 2500
# cold water 2480
# built in 2475
# nbsp nbsp 2428
# inch inch 2426
# package contents 2418
# slightly vary 2402
# care instruction 2392
# brand new 2379
# shop wide 2363
# sleeve type 2347
# vary due 2237
# wash cold 2209
# due photographic 2199
# nbsp strong 2188
# fit type 2171
# made india 2153
# women cotton 2150
# may vary 2146
# strong strong 2138
# closure type 2133
# made high 2129
# color may 2122
# day long 2114
# tempered glass 2095
# occasion casual 2087
# home decor 2084
# great gift 2035
# make sure 2034
# flip flop 2034
# br br 2030
# case cover 2007
# room bedroom 1987
# easy access 1985
# package content 1974
# color black 1973
# please note 1942
# pair stylish 1913
# synthetic leather 1903
# look fabric 1896
# long sleeve 1885
# car cover 1881
# pure cotton 1856
# tumble dry 1853
# eco friendly 1838
# perfect everyday 1833
# cotton lycra 1830
# gift love 1826
# birthday anniversary 1824
# micro usb 1814
# salwar suit 1813
# sling bag 1799
# pattern solid 1776
# type regular 1775
# car seat 1771
# long life 1727
# inch length 1720
# remote control 1706
# dry shade 1699
# unique design 1693
# short sleeve 1687
# strong nbsp 1686
# valentine day 1675
# use could 1675
# could pair 1670
# please check 1664
# connect device 1656
# matte finish 1653
# actual product 1639
# quality fabric 1616
# product make 1608
# clean dry 1607
# flip cover 1585
# available amazon 1581
# soft comfortable 1573
# xiaomi redmi 1571
# keep away 1571
# monitor setting 1563
# special occasion 1561
# long time 1547
# office wear 961
# skin sticker 961
# blue sapphire 959
# faux leather 955
# material leather 954
# one size 954
# easy installation 952
# wear casual 951
# made premium 950
# seat covers 946
# first time 943
# casual shoes 940
# fashion jewellery 938
# every occasion 938
# access button 937
# credit card 937
# style round 937
# material make 937
# sleeve length 937
# wall decor 936
# easy wear 936
# style regular 936
# look stylish 934
# party wedding 932
# dry low 928
# shirt men 927
# neck type 926
# strong product 923
# comfortable fit 919
# product image 914
# package includes 910
# design give 904
# disclaimer product 902
# canvas print 901
# also use 901
# set women 899
# material type 899
# black white 898
# material plastic 891
# back side 889
# ready hang 888
# face mask 887
# cubic zirconia 887
# highly durable 885
# shoulder strap 885
# last long 884
# material high 884
# slightly different 884
# foil balloon 881
# easy apply 879
# mild detergent 879
# wall painting 879
# flip flops 878
# cotton shirt 878
# lead free 874
# design provide 872
# bedsheet pillow 871
# look great 871
# woman girl 871

# %%
# count of top 20 bigrams
plt.bar(bi_grams[0:20], bi_grams_count[0:20])
plt.xticks(rotation = 90)
plt.title("TOP 20 BI-GRAMS")
plt.xlabel("WORDS")
plt.ylabel("COUNT")
plt.show()

# %%
# a histogram depicting number of words in documents
documents_len = x_train.sum(axis=1)
documents_len = np.array(list(documents_len.values))

plt.hist(documents_len)
plt.xlabel("DOCUMENT LENGTH")
plt.ylabel("COUNT")
plt.show()

# %%
length = []
category = []
for i in range(1, 10):
    curr_index = (y_train == i)
    x_curr = x_train.iloc[curr_index]
    y_curr = y_train[curr_index]
    n = x_curr.shape[0]
    arr = []
    for j in range(n):
        arr.append(x_curr.iloc[j].sum())
    length.append(arr)
    category.append(i)
# a box plot representing variations of length of document vs categories
plt.boxplot(length)
plt.xlabel("PRODUCT CLASS")
plt.ylabel("Number of Words in Description")
plt.title("BOXPLOT FOR SIZE OF DESCRIPTION VS CATEGORIES ")
plt.show()

# %% [markdown]
# ## RUNNING MODELS

# %%
#Random Forest Classifier
from yellowbrick.model_selection import validation_curve
from sklearn.ensemble import RandomForestClassifier

# %%
x_train = pd.read_csv('df_train_2.csv')
x_test = pd.read_csv('df_test_2.csv')
y_train = pd.read_csv('y_train.csv', header = None)
y_train = np.array(y_train.values.reshape(-1), dtype = int)
y_test = pd.read_csv('y_test.csv', header = None)
y_test = np.array(y_test.values.reshape(-1), dtype = int)

# %%
# Random Forests with default parameters
rf1 = RandomForestClassifier()
rf1.fit(x_train, y_train)
print(rf1.score(x_train, y_train)) # training score
print(rf1.score(x_test, y_test)) # testing score
# Out:
# 0.9984666666666666
# 0.88488

# %%
"""
now validation curves are made to choose the best value of the parameters
"""

# %%
# changing number of trees
n_trees = [50,100,200,300]
print(validation_curve(RandomForestClassifier(), X = x_train, y = y_train, param_name = 'n_estimators',
                 param_range = n_trees, cv = 5, scoring = "accuracy", n_jobs=-1))
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for RandomForestClassifier'}, xlabel='n_estimators', ylabel='score'>,
#                 cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                 param_name='n_estimators',
#                 param_range=array([ 50, 100, 200, 300]), scoring='accuracy')

# %%
# changing max depth of tree
max_depth = [30,40, 50, 70, 100]
print(validation_curve(RandomForestClassifier(), X = x_train, y = y_train, param_name = 'max_depth',
                 param_range = max_depth, cv = 5, scoring = "accuracy", n_jobs=-1))
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for RandomForestClassifier'}, xlabel='max_depth', ylabel='score'>,
#                 cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                 param_name='max_depth',
#                 param_range=array([ 30,  40,  50,  70, 100]),
#                 scoring='accuracy')

# %%
# changing min_sample_split
min_samples_split = [2,5,10,15,30]
print(validation_curve(RandomForestClassifier(), X = x_train, y = y_train, param_name = 'min_samples_split',
                 param_range = min_samples_split, cv = 5, scoring = "accuracy", n_jobs=-1))
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for RandomForestClassifier'}, xlabel='min_samples_split', ylabel='score'>,
#                 cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                 param_name='min_samples_split',
#                 param_range=array([ 2,  5, 10, 15, 30]), scoring='accuracy')

# %%
# changing min_sample_leaf
min_samples_leaf = [1,2,5,10,15]
print(validation_curve(RandomForestClassifier(), X = x_train, y = y_train, param_name = 'min_samples_leaf',
                 param_range = min_samples_leaf, cv = 5, scoring = "accuracy", n_jobs=-1))
# Out:
# ValidationCurve(ax=<AxesSubplot:title={'center':'Validation Curve for RandomForestClassifier'}, xlabel='min_samples_leaf', ylabel='score'>,
#                 cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                 param_name='min_samples_leaf',
#                 param_range=array([ 1,  2,  5, 10, 15]), scoring='accuracy')

# %%
"""
training with the obtained value of parameters
It can be observed that overfitting is not present when compared to the default parameters
"""
rf1 = RandomForestClassifier(n_estimators=200, max_depth=100, min_samples_split = 5, min_samples_leaf=2)
rf1.fit(x_train, y_train)
print(rf1.score(x_train, y_train)) # training score
print(rf1.score(x_test, y_test)) # testing score
# Out:
# 0.9661333333333333
# 0.87948

# %%
"""
Getting the predictions on training and testing data
"""
y_pred_train = rf1.predict(x_train)
y_pred_test = rf1.predict(x_test)

# %%
"""
Classification report on training data
"""
print("classification_report train")
print(classification_report(y_train, y_pred_train))
# Out:
# classification_report train
#               precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95       735
#            2       0.93      0.93      0.93       755
#            3       0.96      0.99      0.98       779
#            4       0.95      0.99      0.97       752
#            5       0.98      0.99      0.99       767
#            6       0.97      0.98      0.97       730
#            7       0.99      0.99      0.99       743
#            8       0.99      1.00      0.99       754
#            9       0.99      0.99      0.99       741
#           10       0.96      0.98      0.97       753
#           11       0.96      0.96      0.96       738
#           12       0.94      0.93      0.93       744
#           13       1.00      0.99      1.00       742
#           14       0.96      0.95      0.96       762
#           15       0.97      0.97      0.97       769
#           16       0.86      0.72      0.78       729
#           17       0.96      0.96      0.96       729
#           18       0.95      0.97      0.96       782
#           19       0.95      0.92      0.94       759
#           20       0.88      0.93      0.91       759
#           21       0.96      0.97      0.97       739
#           22       0.99      0.99      0.99       757
#           23       0.99      0.99      0.99       744
#           24       0.98      0.98      0.98       737
#           25       0.99      0.99      0.99       732
#           26       0.96      0.97      0.96       745
#           89       0.95      0.97      0.96       273
#           90       0.97      0.97      0.97       239
#           91       0.98      0.97      0.98       256
#           92       0.82      0.83      0.82       237
#           93       0.89      0.84      0.87       233
#           94       0.70      0.94      0.81       240
#           95       0.90      0.91      0.91       246
#           96       0.91      0.94      0.92       262
#           97       0.99      0.99      0.99       256
#           98       0.76      0.74      0.75       276
#           99       0.92      0.95      0.94       230
#          100       0.95      0.97      0.96       254
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.88     25000
# weighted avg       0.88      0.88      0.88     25000

# %%
"""
Decision Tree classifier with the best value of parameters
"""
dt1 = DecisionTreeClassifier(max_depth = 150, min_samples_split = 5, min_samples_leaf=1)
dt1.fit(x_train, y_train)
print(dt1.score(x_train, y_train)) # training score
print(dt1.score(x_test, y_test)) # testing score
# Out:
# 0.9568
# 0.81276

# %%
#Decision Tree Classification Report
y_pred_train = dt1.predict(x_train)
y_pred_test = dt1.predict(x_test)

# %%
print("Decision Tree classification report:training")
print(classification_report(y_train, y_pred_train))
# Out:
# Decision Tree classification report:training
#               precision    recall  f1-score   support
#
#            1       0.94      0.98      0.96       735
#            2       0.92      0.97      0.94       755
#            3       0.97      0.99      0.98       779
#            4       0.97      0.98      0.98       752
#            5       0.98      0.98      0.98       767
#            6       0.93      0.97      0.95       730
#            7       0.97      0.99      0.98       743
#            8       0.98      0.99      0.98       754
#            9       1.00      0.99      0.99       741
#           10       0.89      0.96      0.92       753
#           11       0.90      0.96      0.93       738
#           12       0.91      0.91      0.91       744
#           13       0.99      0.99      0.99       742
#           14       0.92      0.96      0.94       762
#           15       0.92      0.96      0.94       769
#           16       0.38      0.93      0.54       729
#           17       0.96      0.97      0.96       729
#           18       0.97      0.97      0.97       782
#           19       0.94      0.95      0.95       759
#           20       0.93      0.94      0.94       759
#           21       0.93      0.97      0.95       739
#           22       0.99      0.99      0.99       757
#           23       0.99      0.99      0.99       744
#           24       0.96      0.97      0.97       737
#           25       0.97      0.97      0.97       732
#           26       0.95      0.97      0.96       745
#           27       0.98      0.97      0.98       735
#           28       0.93      0.85      0.89       768
#           29       0.97      0.97      0.97       752
#           30       0.96      0.96      0.96       759
#           31       0.95      0.88      0.92       756
#           32       0.94      0.92      0.93       757
#           33       0.93      0.85      0.89       741
#           34       0.95      0.95      0.95       734
#           35       0.94      0.94      0.94       722
#           36       0.97      0.97      0.97       766
#           37       0.97      0.95      0.96       724
#           38       0.97      0.93      0.95       743
#           39       0.98      0.98      0.98       748
#           40       0.98      0.99      0.98       750
#           41       0.98      0.97      0.98       739
#           42       0.95      0.96      0.95       753
#           43       0.99      0.98      0.99       743
#           44       0.96      0.96      0.96       749
#           45       0.93      0.92      0.92       761
#           46       0.97      0.97      0.97       759
#           47       0.97      0.94      0.96       765
#           48       0.99      0.97      0.98       734
#           49       0.99      0.98      0.99       757
#           50       0.97      0.94      0.96       723
#           51       0.97      0.96      0.96       757
#           52       0.97      0.94      0.96       779
#           53       0.97      0.92      0.95       756
#           54       0.96      0.92      0.94       744
#           32       0.59      0.65      0.62       243
#           33       0.72      0.70      0.71       259
#           34       0.72      0.70      0.71       266
#           35       0.67      0.59      0.62       278
#           36       0.87      0.87      0.87       234
#           37       0.76      0.70      0.72       276
#           38       0.61      0.61      0.61       257
#           39       0.94      0.89      0.92       252
#           40       0.87      0.92      0.89       250
#           41       0.92      0.88      0.90       261
#           42       0.64      0.72      0.68       247
#           43       0.93      0.94      0.93       257
#           44       0.83      0.80      0.82       251
#           45       0.61      0.62      0.61       239
#           46       0.90      0.85      0.87       241
#           47       0.76      0.74      0.75       235
#           48       0.93      0.92      0.93       266
#           49       0.98      0.96      0.97       243
#           50       0.81      0.81      0.81       277
#           51       0.90      0.81      0.85       243
#           52       0.76      0.74      0.75       221
#           53       0.69      0.73      0.71       244
#           54       0.72      0.65      0.68       256
#           55       0.90      0.92      0.91       270
#           56       0.87      0.87      0.87       232
#           57       0.97      0.91      0.94       244
#           58       0.91      0.93      0.92       261
#           59       0.67      0.61      0.64       239
#           60       0.84      0.84      0.84       238
#           61       0.71      0.72      0.71       260
#           62       0.96      0.89      0.92       270
#           63       0.88      0.87      0.88       246
#           64       0.84      0.78      0.81       247
#           65       0.93      0.91      0.92       231
#           66       0.96      0.96      0.96       254
#           67       0.87      0.86      0.86       240
#           68       0.90      0.89      0.90       214
#           69       0.98      0.95      0.96       246
#           70       0.94      0.95      0.94       239
#           71       0.91      0.91      0.91       229
#           72       0.90      0.89      0.89       259
#           73       0.88      0.79      0.83       240
#           74       0.71      0.74      0.72       244
#           75       0.80      0.78      0.79       264
#           76       0.95      0.94      0.95       237
#           77       0.73      0.78      0.76       222
#           78       0.97      0.93      0.95       253
#           79       0.62      0.56      0.59       253
#           80       0.90      0.90      0.90       241
#           81       0.85      0.81      0.83       231
#           82       0.79      0.73      0.76       276
#           83       0.95      0.92      0.93       266
#           84       0.72      0.69      0.70       272
#           85       0.90      0.85      0.87       246
#           86       0.94      0.88      0.91       264
#           87       0.87      0.85      0.86       266
#           88       0.80      0.74      0.77       254
#           89       0.91      0.92      0.92       273
#           90       0.96      0.94      0.95       239
#           91       0.97      0.94      0.96       256
#           92       0.75      0.87      0.81       237
#           93       0.82      0.80      0.81       233
#           94       0.84      0.75      0.79       240
#           95       0.82      0.80      0.81       246
#           96       0.94      0.82      0.88       262
#           97       0.99      0.98      0.98       256
#           98       0.73      0.69      0.71       276
#           99       0.94      0.92      0.93       230
#          100       0.94      0.96      0.95       254
#
#     accuracy                           0.81     25000
#    macro avg       0.82      0.81      0.82     25000
# weighted avg       0.82      0.81      0.82     25000

# %%
"""
MLP classifier with default parameters
"""
clf = MLPClassifier()
clf.fit(x_train, y_train)
# Out:
# MLPClassifier()

# %%
"""
Score on training and testing data
"""
print(clf.score(x_train, y_train))
print(clf.score(x_test, y_test))
# Out:
# 0.9958933333333333
# 0.85616

# %%
param_grid = {'hidden_layer_sizes' : [(64, 32, )],
             'activation': ['tanh', 'relu', 'sigmoid'],
             'alpha': [0.0001, 0.001, 0.01], 
             'learning_rate_init' : [0.001, 0.01]}
clf = MLPClassifier()
grid_search = GridSearchCV(clf, param_grid, scoring="accuracy", return_train_score=True, verbose=True)
grid_search.fit(x_train, y_train)

# %%
"""
MLP classifier with changed parameters
"""
clf = MLPClassifier(hidden_layer_sizes=[64, 32, ], activation='logistic', max_iter=150)
clf.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=[64, 32], max_iter=150)

# %%
print(clf.score(x_train, y_train))
print(clf.score(x_test, y_test))
# Out:
# 0.99696
# 0.85592

# %%
"""
It can be observed that both the neural networks are performing similarly and apperar to be overfitting
the training data
"""

# %%
#KNN 
clf_knn = KNeighborsClassifier()
clf_knn.fit(x_train, y_train)
# print("KNN-score")
# print("training score:" , clf_knn.score(x_train, y_train))
print("testing score:", clf_knn.score(x_test, y_test))
# Out:
# testing score: 0.75972

# %%
"""
Predictions using KNN
"""
# y_train_pred_knn = clf_knn.predict(x_train)
y_test_pred_knn = clf_knn.predict(x_test)

# %%
print("Training data classification report")
print(classification_report(y_train, y_train_pred_knn))

# %%
print("Testing data classification report")
print(classification_report(y_test, y_test_pred_knn))
# Out:
# Testing data classification report
#               precision    recall  f1-score   support
#
#            1       0.75      0.77      0.76       265
#            2       0.56      0.61      0.58       245
#            3       0.84      0.91      0.88       221
#            4       0.87      0.85      0.86       248
#            5       0.86      0.95      0.90       233
#            6       0.74      0.70      0.72       270
#            7       0.91      0.89      0.90       257
#            8       0.87      0.94      0.90       246
#            9       0.96      0.91      0.93       259
#           10       0.65      0.67      0.66       247
#           11       0.64      0.69      0.66       262
#           12       0.54      0.71      0.61       256
#           13       0.99      0.93      0.96       258
#           14       0.67      0.69      0.68       238
#           15       0.36      0.45      0.40       231
#           16       0.13      0.27      0.17       271
#           17       0.72      0.80      0.76       271
#           18       0.76      0.82      0.79       218
#           19       0.83      0.73      0.78       241
#           20       0.60      0.64      0.62       241
#           21       0.62      0.67      0.64       261
#           22       0.98      0.95      0.97       243
#           23       0.98      0.98      0.98       256
#           24       0.65      0.76      0.70       263
#           25       0.98      0.92      0.95       268
#           26       0.73      0.80      0.77       255
#           27       0.90      0.75      0.82       265
#           28       0.42      0.44      0.43       232
#           29       0.78      0.78      0.78       248
#           30       0.90      0.76      0.83       241
#           31       0.82      0.57      0.68       244
#           32       0.42      0.51      0.46       243
#           33       0.29      0.78      0.42       259
#           34       0.74      0.71      0.73       266
#           35       0.65      0.58      0.61       278
#           36       0.88      0.75      0.81       234
#           37       0.75      0.67      0.71       276
#           38       0.57      0.37      0.45       257
#           39       0.93      0.91      0.92       252
#           40       0.88      0.93      0.90       250
#           41       0.98      0.87      0.92       261
#           42       0.61      0.57      0.59       247
#           43       0.95      0.91      0.93       257
#           44       0.66      0.67      0.66       251
#           45       0.62      0.49      0.55       239
#           46       0.73      0.73      0.73       241
#           47       0.77      0.68      0.72       235
#           48       0.94      0.85      0.89       266
#           49       0.98      0.86      0.92       243
#           50       0.74      0.77      0.76       277
#           51       0.98      0.78      0.87       243
#           52       0.63      0.69      0.66       221
#           53       0.71      0.76      0.74       244
#           54       0.75      0.57      0.65       256
#           55       0.83      0.78      0.80       270
#           56       0.72      0.76      0.74       232
#           57       0.98      0.90      0.94       244
#           58       0.98      0.93      0.95       261
#           59       0.67      0.54      0.59       239
#           60       0.87      0.82      0.84       238
#           61       0.72      0.73      0.72       260
#           62       0.93      0.89      0.91       270
#           63       0.93      0.73      0.82       246
#           64       0.76      0.74      0.75       247
#           65       0.90      0.90      0.90       231
#           66       0.93      0.97      0.95       254
#           67       0.86      0.90      0.88       240
#           68       0.80      0.88      0.84       214
#           69       0.99      0.93      0.96       246
#           70       0.95      0.95      0.95       239
#           71       0.87      0.81      0.84       229
#           72       0.95      0.83      0.88       259
#           73       0.74      0.55      0.63       240
#           74       0.69      0.63      0.66       244
#           75       0.75      0.59      0.66       264
#           76       0.91      0.95      0.93       237
#           77       0.75      0.77      0.76       222
#           78       0.96      0.95      0.96       253
#           79       0.55      0.48      0.51       253
#           80       0.96      0.86      0.91       241
#           81       0.74      0.52      0.61       231
#           82       0.69      0.53      0.60       276
#           83       0.96      0.92      0.94       266
#           84       0.74      0.69      0.72       272
#           85       0.88      0.82      0.85       246
#           86       0.88      0.86      0.87       264
#           87       0.82      0.73      0.77       266
#           88       0.78      0.69      0.73       254
#           89       0.92      0.81      0.86       273
#           90       0.89      0.87      0.88       239
#           91       0.96      0.92      0.94       256
#           92       0.75      0.77      0.76       237
#           93       0.74      0.67      0.70       233
#           94       0.40      0.85      0.54       240
#           95       0.86      0.76      0.81       246
#           96       0.91      0.72      0.81       262
#           97       0.97      0.95      0.96       256
#           98       0.68      0.61      0.64       276
#           99       0.93      0.91      0.92       230
#          100       0.94      0.94      0.94       254
#
#     accuracy                           0.76     25000
#    macro avg       0.79      0.76      0.77     25000
# weighted avg       0.79      0.76      0.77     25000

# %%
"""
SVM classifier
"""
clf_svm = SVC()
clf_svm.fit(x_train, y_train)
train_score = clf_svm.score(x_train, y_train)
test_score = clf_svm.score(x_test, y_test)

# %%
print("Training score:", train_score)
print("Testing score:", test_score)

# %%
y_pred_train_svm = clf_svm.predict(x_train)
y_pred_test_svm = clf_svm.predict(x_test)

# %%
print("Training data classification report")
print(classification_report(y_train, y_pred_train_svm))

# %%
print("Testing data classification report")
print(classification_report(y_test, y_pred_test_svm))

# %% [markdown]
# ## Saving Models

# %%
import joblib

# %%
#saving random forests model
joblib_file = "rf_model.pkl"  
joblib.dump(rf1, joblib_file)
# Out:
# ['rf_model.pkl']

# %%
#saving mlp classifier 
joblib_file = "mlp_model.pkl"  
joblib.dump(clf, joblib_file)
# Out:
# ['mlp_model.pkl']

# %%
#saving decision tree classifier 
joblib_file = "decisionTree_model.pkl"  
joblib.dump(dt1, joblib_file)
# Out:
# ['decisionTree_model.pkl']

# %%
#saving knn 
joblib_file = "knn_model.pkl"  
joblib.dump(clf_knn, joblib_file)
# Out:
# ['knn_model.pkl']

# %%
#saving svm model
joblib_file = "svm_model.pkl"  
joblib.dump(clf_svm, joblib_file)
